# %%
# !pip3 install folium
# Out:
# Requirement already satisfied: folium in /Users/dayo2n/opt/anaconda3/lib/python3.8/site-packages (0.12.1.post1)
# Requirement already satisfied: numpy in /Users/dayo2n/opt/anaconda3/lib/python3.8/site-packages (from folium) (1.19.2)
# Requirement already satisfied: requests in /Users/dayo2n/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.27.1)
# Requirement already satisfied: branca>=0.3.0 in /Users/dayo2n/opt/anaconda3/lib/python3.8/site-packages (from folium) (0.4.2+10.gb58682d)
# Requirement already satisfied: jinja2>=2.9 in /Users/dayo2n/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.11.2)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /Users/dayo2n/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dayo2n/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/dayo2n/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /Users/dayo2n/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/dayo2n/opt/anaconda3/lib/python3.8/site-packages (from jinja2>=2.9->folium) (1.1.1)

# %%
import numpy as np
import pandas as pd
import folium

# %%
import warnings

warnings.filterwarnings(action='ignore')

# %%
# !pip3 install git+https://github.com/python-visualization/branca.git@master
# Out:
# Collecting git+https://github.com/python-visualization/branca.git@master
#   Cloning https://github.com/python-visualization/branca.git (to revision master) to /private/var/folders/jp/h93dszws35j0g9067z2hn9240000gn/T/pip-req-build-gogxymbq
# Requirement already satisfied (use --upgrade to upgrade): branca==0.4.2+10.gb58682d from git+https://github.com/python-visualization/branca.git@master in /Users/dayo2n/opt/anaconda3/lib/python3.8/site-packages
# Requirement already satisfied: jinja2 in /Users/dayo2n/opt/anaconda3/lib/python3.8/site-packages (from branca==0.4.2+10.gb58682d) (2.11.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/dayo2n/opt/anaconda3/lib/python3.8/site-packages (from jinja2->branca==0.4.2+10.gb58682d) (1.1.1)
# Building wheels for collected packages: branca
#   Building wheel for branca (setup.py) ... done
#   Created wheel for branca: filename=branca-0.4.2+10.gb58682d-py3-none-any.whl size=24385 sha256=aad944fa1b04e1bca64a76800599ea18176853ee2c52ae1e9f6ea46e2a6e97ba
#   Stored in directory: /private/var/folders/jp/h93dszws35j0g9067z2hn9240000gn/T/pip-ephem-wheel-cache-lyqdrlya/wheels/bb/6c/24/b1ebc2f0d22fedfda893eafa058dcaf1a1f9df9fc66ae1f7b4
# Successfully built branca

# %%
m = folium.Map(
    location = [33.36362781630753, 126.52916657111979] # 구글 지도에 한라산 검색 후 (위도, 경도) 복붙
)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_617e9cb0953c4ac08768d93497a785ba%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_617e9cb0953c4ac08768d93497a785ba%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_617e9cb0953c4ac08768d93497a785ba%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_617e9cb0953c4ac08768d93497a785ba%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B33.36362781630753%2C%20126.52916657111979%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
m.save('index.html')
# 지도가 html 파일로 저장된다.

# %%
# 지도에 한라산 마커 찍기
m = folium.Map(
    location = [33.36362781630753, 126.52916657111979],
    tiles = 'Stamen Terrain', # 지형을 바꿔주는 코드
    zoom_start = 10
)

tooltip = 'Click!!'

folium.Marker(
    [33.36362781630753, 126.52916657111979],
    popup = '<strong>hello world</strong>',
    tooltip = tooltip
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7588ad7faeda13f71782b1a1d514132d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7588ad7faeda13f71782b1a1d514132d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7588ad7faeda13f71782b1a1d514132d = L.map(
#                 &quot;map_7588ad7faeda13f71782b1a1d514132d&quot;,
#                 {
#                     center: [33.36362781630753, 126.52916657111979],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef536590bb0c69907dd4d57f4770c0b9 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7588ad7faeda13f71782b1a1d514132d);
#
#
#             var marker_6e33613d1b4397d981ed29712f5dd160 = L.marker(
#                 [33.36362781630753, 126.52916657111979],
#                 {}
#             ).addTo(map_7588ad7faeda13f71782b1a1d514132d);
#
#
#         var popup_6b4bd0f1b2e041dd5f76595628219ed3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7e647f75eba0369e42692fa985bbf0e4 = $(`&lt;div id=&quot;html_7e647f75eba0369e42692fa985bbf0e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;hello world&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_6b4bd0f1b2e041dd5f76595628219ed3.setContent(html_7e647f75eba0369e42692fa985bbf0e4);
#
#
#         marker_6e33613d1b4397d981ed29712f5dd160.bindPopup(popup_6b4bd0f1b2e041dd5f76595628219ed3)
#         ;
#
#
#
#
#             marker_6e33613d1b4397d981ed29712f5dd160.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 마커를 여러개 찍어보자
m = folium.Map(
    location = [33.36362781630753, 126.52916657111979],
#     tiles = 'Stamen Terrain', # 지형을 바꿔주는 코드
    zoom_start = 10
)

tooltip = 'Click!!'

folium.Marker(
    [33.36362781630753, 126.52916657111979],
    popup = '<strong>한라산</strong>',
    tooltip = tooltip
).add_to(m)

folium.Marker(
    [33.51049098299758, 126.49135573869128],
    popup = '<strong>제주 국제 공항</strong>',
    tooltip = tooltip
).add_to(m)

folium.Marker(
    [33.50504836804892, 126.95430546321592],
    popup = '<strong>우도</strong>',
    tooltip = tooltip
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_92256f645258485d90a99e19f6bbd1d0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_92256f645258485d90a99e19f6bbd1d0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_92256f645258485d90a99e19f6bbd1d0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_92256f645258485d90a99e19f6bbd1d0%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B33.36362781630753%2C%20126.52916657111979%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# 마커의 종류를 바꿔보자
m = folium.Map(
    location = [33.36362781630753, 126.52916657111979],
#     tiles = 'Stamen Terrain', # 지형을 바꿔주는 코드
    zoom_start = 10
)

tooltip = 'Click!!'

folium.Marker(
    [33.36362781630753, 126.52916657111979],
    popup = '<strong>한라산</strong>',
    tooltip = tooltip,
    icon = folium.Icon(color='#ff0000',icon='info-mark')
).add_to(m)

folium.Marker(
    [33.51049098299758, 126.49135573869128],
    popup = '<strong>제주 국제 공항</strong>',
    tooltip = tooltip,
    icon = folium.Icon(color='#ffffff',icon='book-mark')
).add_to(m)

folium.Marker(
    [33.50504836804892, 126.95430546321592],
    popup = '<strong>우도</strong>',
    tooltip = tooltip,
    icon = folium.Icon(color='#ffffff')
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_164e133761b6b6dfc0aa0aa2363c01a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_164e133761b6b6dfc0aa0aa2363c01a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_164e133761b6b6dfc0aa0aa2363c01a7 = L.map(
#                 &quot;map_164e133761b6b6dfc0aa0aa2363c01a7&quot;,
#                 {
#                     center: [33.36362781630753, 126.52916657111979],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d99ed8a0109c02292d7f7faf8cd80b6c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_164e133761b6b6dfc0aa0aa2363c01a7);
#
#
#             var marker_a530af628a7afb06217ec233ff02eb68 = L.marker(
#                 [33.36362781630753, 126.52916657111979],
#                 {}
#             ).addTo(map_164e133761b6b6dfc0aa0aa2363c01a7);
#
#
#             var icon_fc016fa89114900ce4080351fe6a8721 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-mark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;#ff0000&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a530af628a7afb06217ec233ff02eb68.setIcon(icon_fc016fa89114900ce4080351fe6a8721);
#
#
#         var popup_3ebfd5140b1320b7470945efa263343a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dff1b261351c5b2669b884e1fbd83bd5 = $(`&lt;div id=&quot;html_dff1b261351c5b2669b884e1fbd83bd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;한라산&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_3ebfd5140b1320b7470945efa263343a.setContent(html_dff1b261351c5b2669b884e1fbd83bd5);
#
#
#         marker_a530af628a7afb06217ec233ff02eb68.bindPopup(popup_3ebfd5140b1320b7470945efa263343a)
#         ;
#
#
#
#
#             marker_a530af628a7afb06217ec233ff02eb68.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_90c0ad52e616bdeeaf6a221b06672708 = L.marker(
#                 [33.51049098299758, 126.49135573869128],
#                 {}
#             ).addTo(map_164e133761b6b6dfc0aa0aa2363c01a7);
#
#
#             var icon_e919f7e6a1003fe75aeb8a4ea2d5a18f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;book-mark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;#ffffff&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_90c0ad52e616bdeeaf6a221b06672708.setIcon(icon_e919f7e6a1003fe75aeb8a4ea2d5a18f);
#
#
#         var popup_1489626bc25056dcde39451272a417cc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_982672322a9e3e8c78f9cbca568f5cbd = $(`&lt;div id=&quot;html_982672322a9e3e8c78f9cbca568f5cbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;제주 국제 공항&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_1489626bc25056dcde39451272a417cc.setContent(html_982672322a9e3e8c78f9cbca568f5cbd);
#
#
#         marker_90c0ad52e616bdeeaf6a221b06672708.bindPopup(popup_1489626bc25056dcde39451272a417cc)
#         ;
#
#
#
#
#             marker_90c0ad52e616bdeeaf6a221b06672708.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_317151dfd5a0336d514523a4302f5996 = L.marker(
#                 [33.50504836804892, 126.95430546321592],
#                 {}
#             ).addTo(map_164e133761b6b6dfc0aa0aa2363c01a7);
#
#
#             var icon_9842e80db55bbd95e958cf1da8c6fb73 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;#ffffff&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_317151dfd5a0336d514523a4302f5996.setIcon(icon_9842e80db55bbd95e958cf1da8c6fb73);
#
#
#         var popup_cf43efaf3383cc6c6d68eacd0863806f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_80a69f5b253b71457a5063d0297fc2f6 = $(`&lt;div id=&quot;html_80a69f5b253b71457a5063d0297fc2f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;우도&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_cf43efaf3383cc6c6d68eacd0863806f.setContent(html_80a69f5b253b71457a5063d0297fc2f6);
#
#
#         marker_317151dfd5a0336d514523a4302f5996.bindPopup(popup_cf43efaf3383cc6c6d68eacd0863806f)
#         ;
#
#
#
#
#             marker_31
